# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_2_root = '../'
path_2_data = path_2_root + 'data/csv/IEA/'
filename = 'Global Energy Review 2025 Dataset.xlsx'
full_filename = path_2_data + filename
sheet_name = 'World'
df = pd.read_excel(full_filename, sheet_name=sheet_name)
df.head(10)
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2   Unnamed: 3           Unnamed: 4  \
# 0         NaN  Publication   Category      Product                 Flow
# 1         NaN      GER2025     Energy        Total  Total energy supply
# 2         NaN          NaN        NaN   Renewables                  NaN
# 3         NaN      GER2025     Energy      Nuclear  Total energy supply
# 4         NaN      GER2025     Energy  Natural gas  Total energy supply
# 5         NaN      GER2025     Energy          Oil  Total energy supply
# 6         NaN      GER2025     Energy         Coal  Total energy supply
# 7         NaN          NaN        NaN          NaN                  NaN
# 8         NaN          NaN        NaN          NaN                  NaN
# 9         NaN  Publication   Category      Product                 Flow
#
#   Unnamed: 5 Unnamed: 6  Unnamed: 7   Unnamed: 8  \
# 0       Unit     Region         NaN          NaN
# 1         PJ      World         NaN        Total
# ...
